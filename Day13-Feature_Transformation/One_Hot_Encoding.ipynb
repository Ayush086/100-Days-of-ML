# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('cars.csv')

# %%
df.head()
# Out:
#      brand  km_driven    fuel         owner  selling_price
# 0   Maruti     145500  Diesel   First Owner         450000
# 1    Skoda     120000  Diesel  Second Owner         370000
# 2    Honda     140000  Petrol   Third Owner         158000
# 3  Hyundai     127000  Diesel   First Owner         225000
# 4   Maruti     120000  Petrol   First Owner         130000

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             5289
# Second Owner            2105
# Third Owner              555
# Fourth & Above Owner     174
# Test Drive Car             5
# Name: count, dtype: int64

# %% [markdown]
# # 1. OneHotEncoding using Pandas

# %%
pd.get_dummies(df, columns=['fuel', 'owner']) # not performing on owner column because it has many unique categories
# Out:
#         brand  km_driven  selling_price  fuel_CNG  fuel_Diesel  fuel_LPG  \
# 0      Maruti     145500         450000     False         True     False
# 1       Skoda     120000         370000     False         True     False
# 2       Honda     140000         158000     False        False     False
# 3     Hyundai     127000         225000     False         True     False
# 4      Maruti     120000         130000     False        False     False
# ...       ...        ...            ...       ...          ...       ...
# 8123  Hyundai     110000         320000     False        False     False
# 8124  Hyundai     119000         135000     False         True     False
# 8125   Maruti     120000         382000     False         True     False
# 8126     Tata      25000         290000     False         True     False
# 8127     Tata      25000         290000     False         True     False
#
#       fuel_Petrol  owner_First Owner  owner_Fourth & Above Owner  \
# 0           False               True                       False
# 1           False              False                       False
# 2            True              False                       False
# 3           False               True                       False
# 4            True               True                       False
# ...           ...                ...                         ...
# 8123         True               True                       False
# 8124        False              False                        True
# 8125        False               True                       False
# 8126        False               True                       False
# 8127        False               True                       False
#
#       owner_Second Owner  owner_Test Drive Car  owner_Third Owner
# 0                  False                 False              False
# 1                   True                 False              False
# 2                  False                 False               True
# 3                  False                 False              False
# 4                  False                 False              False
# ...                  ...                   ...                ...
# 8123               False                 False              False
# 8124               False                 False              False
# 8125               False                 False              False
# 8126               False                 False              False
# 8127               False                 False              False
#
# [8128 rows x 12 columns]

# %% [markdown]
# # 2. K-1 OneHotEncoding

# %%
pd.get_dummies(df, columns=['fuel', 'owner'], drop_first=True) # n-1 categories
# Out:
#         brand  km_driven  selling_price  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# 0      Maruti     145500         450000         True     False        False
# 1       Skoda     120000         370000         True     False        False
# 2       Honda     140000         158000        False     False         True
# 3     Hyundai     127000         225000         True     False        False
# 4      Maruti     120000         130000        False     False         True
# ...       ...        ...            ...          ...       ...          ...
# 8123  Hyundai     110000         320000        False     False         True
# 8124  Hyundai     119000         135000         True     False        False
# 8125   Maruti     120000         382000         True     False        False
# 8126     Tata      25000         290000         True     False        False
# 8127     Tata      25000         290000         True     False        False
#
#       owner_Fourth & Above Owner  owner_Second Owner  owner_Test Drive Car  \
# 0                          False               False                 False
# 1                          False                True                 False
# 2                          False               False                 False
# 3                          False               False                 False
# 4                          False               False                 False
# ...                          ...                 ...                   ...
# 8123                       False               False                 False
# 8124                        True               False                 False
# 8125                       False               False                 False
# 8126                       False               False                 False
# 8127                       False               False                 False
#
#       owner_Third Owner
# 0                 False
# 1                 False
# 2                  True
# 3                 False
# 4                 False
# ...                 ...
# 8123              False
# 8124              False
# 8125              False
# 8126              False
# 8127              False
#
# [8128 rows x 10 columns]

# %% [markdown]
# # 3. OHE using Sklearn

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:, 0:4], df.iloc[:, -1], test_size = 0.2, random_state = 2)

# %%
X_train.head()
# Out:
#          brand  km_driven    fuel         owner
# 5571   Hyundai      35000  Diesel   First Owner
# 2038      Jeep      60000  Diesel   First Owner
# 2957   Hyundai      25000  Petrol   First Owner
# 7618  Mahindra     130000  Diesel  Second Owner
# 6684   Hyundai     155000  Diesel   First Owner

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder(drop='first', dtype=np.int32)

# %%
X_train_new = ohe.fit_transform(X_train[['fuel', 'owner']]).toarray()

# %%
X_test_new = ohe.transform(X_test[['fuel', 'owner']]).toarray()

# %%
X_train_new.shape
# Out:
# (6502, 7)

# %%
np.hstack((X_train[['brand', 'km_driven']].values, X_train_new))
# Out:
# array([['Hyundai', 35000, 1, ..., 0, 0, 0],
#        ['Jeep', 60000, 1, ..., 0, 0, 0],
#        ['Hyundai', 25000, 0, ..., 0, 0, 0],
#        ...,
#        ['Tata', 15000, 0, ..., 0, 0, 0],
#        ['Maruti', 32500, 1, ..., 1, 0, 0],
#        ['Isuzu', 121000, 1, ..., 0, 0, 0]], dtype=object)

# %% [markdown]
# # OHE with Top Categories

# %% [markdown]
# It is performed when categories types are very high

# %%
counts = df['brand'].value_counts()

# %%
# creating a threshold where if category's value count < 100 will be considered under 'other' category
df['brand'].nunique()
threshold = 100

# %%
# categories with < threshold
repl = counts[counts <= threshold].index

# %%
repl
# Out:
# Index(['Nissan', 'Jaguar', 'Volvo', 'Datsun', 'Mercedes-Benz', 'Fiat', 'Audi',
#        'Lexus', 'Jeep', 'Mitsubishi', 'Force', 'Land', 'Isuzu', 'Kia',
#        'Ambassador', 'Daewoo', 'MG', 'Ashok', 'Opel', 'Peugeot'],
#       dtype='object', name='brand')

# %%
pd.get_dummies(df['brand'].replace(repl, 'uncommon')).sample(20)
# Out:
#         BMW  Chevrolet   Ford  Honda  Hyundai  Mahindra  Maruti  Renault  \
# 1695  False      False  False  False    False      True   False    False
# 2717  False      False  False  False    False     False    True    False
# 4556  False      False  False  False    False     False   False    False
# 2849  False      False  False  False    False     False    True    False
# 8026  False      False  False  False    False     False   False    False
# 2624  False      False  False  False    False     False    True    False
# 6840  False      False  False  False     True     False   False    False
# 2435  False      False   True  False    False     False   False    False
# 7897  False      False  False  False    False     False    True    False
# 4155  False      False  False  False    False     False   False    False
# 2570  False      False  False  False    False      True   False    False
# 2578  False      False  False  False     True     False   False    False
# 5440  False      False  False  False     True     False   False    False
# 5227  False      False  False  False    False     False    True    False
# 3203  False      False  False  False    False     False   False    False
# 3623  False      False  False  False    False      True   False    False
# 1040  False      False  False  False    False      True   False    False
# 2648  False      False  False  False    False     False   False    False
# 5426  False      False  False  False     True     False   False    False
# 1288  False      False  False  False    False     False    True    False
#
#       Skoda   Tata  Toyota  Volkswagen  uncommon
# 1695  False  False   False       False     False
# 2717  False  False   False       False     False
# 4556  False   True   False       False     False
# 2849  False  False   False       False     False
# 8026  False   True   False       False     False
# 2624  False  False   False       False     False
# 6840  False  False   False       False     False
# 2435  False  False   False       False     False
# 7897  False  False   False       False     False
# 4155  False   True   False       False     False
# 2570  False  False   False       False     False
# 2578  False  False   False       False     False
# 5440  False  False   False       False     False
# 5227  False  False   False       False     False
# 3203  False  False    True       False     False
# 3623  False  False   False       False     False
# 1040  False  False   False       False     False
# 2648  False  False   False       False      True
# 5426  False  False   False       False     False
# 1288  False  False   False       False     False
